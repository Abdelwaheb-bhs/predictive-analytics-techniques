# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdelwaheb-bhs/predictive-analytics-techniques/blob/main/Extreme%20point/Abdelwaheb_benhajsaid_Tp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TP3**
#
# ### Soit la série suivante :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = {'t': [1,2,3,4,5,6,7], 'CA': [120,155,125,202,180,235,240]}
df=pd.DataFrame(data)
df
# Out:
#    t   CA
# 0  1  120
# 1  2  155
# 2  3  125
# 3  4  202
# 4  5  180
# 5  6  235
# 6  7  240

# %% [markdown]
# ### 1. Représenter graphiquement la série par un nuage de points.

# %%
plt.scatter(df['t'], df['CA'])
plt.xlabel('t')
plt.ylabel('CA')
plt.title('Nuage de points')
plt.show()

# %% [markdown]
# ### 2. Déterminer l’équation de la droite de tendance en utilisant la méthode des points extrêmes.

# %%
Y1=df.iloc[len(df)-1,1]
Y2=df.iloc[0, 1]
X2=df.iloc[0, 0]
X1=df.iloc[len(df)-1,0]
a=(Y1-Y2)/(X1-X2)
b=Y1-a*X1
print(X1,X2,Y1,Y2,a)
print(f"l’équation de l’ajustement : Y= {a}X + {b} ")
df
# Out:
# 7 1 240 120 20.0
# l’équation de l’ajustement : Y= 20.0X + 100.0
#    t   CA
# 0  1  120
# 1  2  155
# 2  3  125
# 3  4  202
# 4  5  180
# 5  6  235
# 6  7  240

# %% [markdown]
# ### 3. Représenter cette équation sur le même graphique.

# %%
t_line = np.linspace(1, 8, 100)
CA_line = a * t_line + b
sns.scatterplot(x=df['t'], y= df['CA'], label='Données')
sns.lineplot(x=t_line, y=CA_line, color='red', label=f'Droite de tendance: y = {a:.2f}x + {b:.2f}')
# Out:
# <Axes: xlabel='t', ylabel='CA'>

# %% [markdown]
# ### **Déterminer la prévision pour t=8.**

# %%
t_8 = 8
CA_8 = a * t_8 + b
CA_8
# Out:
# 260.0
